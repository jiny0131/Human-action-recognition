# %%
import pandas as pd
import numpy as np
from tensorflow import keras
train_total = pd.read_csv("train.csv", header = None)

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Split data into train and development dataset

# %%
from sklearn.model_selection import KFold
import numpy as np
from sklearn import utils
shuffle_data = utils.shuffle(train_total)
# k fold cross validation
feature = shuffle_data.iloc[:,1:-1]
label = shuffle_data.iloc[:,-1:]
kf = KFold(n_splits=10,shuffle=True)
count = 1
for train_index, dev_index in kf.split(shuffle_data):
    train_feature, dev_feature = np.array(feature.iloc[train_index]), np.array(feature.iloc[dev_index])
    train_label, dev_label = np.array(label.iloc[train_index].values.ravel()), np.array(label.iloc[dev_index].values.ravel())

# %% [markdown]
# ## Handling of unbalanced data by oversampling

# %%
from imblearn.over_sampling import SMOTE
train_feature, train_label = SMOTE().fit_resample(train_feature,train_label)

# %% [markdown]
# ## reshape the format of data that can be used in deep learning model

# %%
def reshape_feature(feature):
    reshape_f = []
    for f in feature:
        reshape_f.append(f.reshape(16,60))
    reshape_f = np.array(reshape_f)
    return reshape_f
def generate_label(label):
    new_label = []
    for l in label:
        new_label.append(l-1)
    return np.array(new_label)

# %%
reshape_train_feature = reshape_feature(train_feature)
reshape_dev_feature = reshape_feature(dev_feature)
reshape_train_label = keras.utils.to_categorical(generate_label(train_label))
reshape_dev_label = keras.utils.to_categorical(generate_label(dev_label))

# %% [markdown]
# # Recurrent Neural Network(RNN)

# %%
from tensorflow.keras import initializers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dropout, LSTM, Dense,Activation,TimeDistributed,Masking,Concatenate
from tensorflow.keras.callbacks import EarlyStopping,CSVLogger,ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import layers

# %%
class MeanOverTime(Layer):
    """Average the score of every step"""
    def __init__(self, **kwargs):
        self.supports_masking = True

        super(MeanOverTime, self).__init__(**kwargs)

    def call(self, inputs, mask=None):
        x = K.sum(inputs, axis=1)
        mask = K.cast(mask, K.floatx())
        mask = K.sum(mask, axis=1, keepdims=True)
        output = x / mask
        return output

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[2])

    def compute_mask(self, x, mask):
        return None

    def get_config(self):
        config = {}
        base_config = super(MeanOverTime, self).get_config()
        return dict(list(base_config.items()))

# %%
class Noise(Layer):
    """Add Guassian Noise"""

    def __init__(self, sigma, **kwargs):
        self.supports_masking = True
        self.sigma = sigma
        self.uses_learning_phase = True
        super(Noise, self).__init__(**kwargs)

    def compute_mask(self, input, mask):
        return mask

    def call(self, x, mask=None, training=None):
        m = K.not_equal(x, 0.)
        noise_x = x + K.random_normal(shape=K.shape(x),
                                      mean=0.,
                                      stddev=self.sigma)
        noise_x = noise_x * K.cast(m, K.floatx())

        return K.in_train_phase(noise_x, x, training=training)

    def get_config(self):
        config = {'sigma': self.sigma}
        base_config = super(Noise, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
def create_model(input_shape, num_class):

    init = initializers.Orthogonal(gain=0.001)
    sequence_input =Input(shape=input_shape)
    mask = Masking(mask_value=0.)(sequence_input)
    X = Noise(0.075)(mask)

    X = LSTM(100,recurrent_activation='sigmoid',return_sequences=True,implementation=2,recurrent_initializer=init)(X)
    X = Dropout(0.5)(X)
    X = LSTM(100,recurrent_activation='sigmoid',return_sequences=True,implementation=2,recurrent_initializer=init)(X)
    X = Dropout(0.5)(X)
    X = LSTM(100,recurrent_activation='sigmoid',return_sequences=True,implementation=2,recurrent_initializer=init)(X)
    X = Dropout(0.5)(X)
    X = TimeDistributed(Dense(num_class))(X)
    X = MeanOverTime()(X)
    X = Activation('softmax')(X)
    
    model=Model(sequence_input,X)
    return model

# %%
rnn = create_model((16,60), 49)

# %%
optimizer = Adam(lr=0.001, clipnorm=1.)

early_stop = EarlyStopping(monitor='val_accuracy', patience=15, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5, mode='auto', cooldown=3., verbose=1)
callbacks_list = [early_stop, reduce_lr]

# %%
rnn.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
rnn.fit(reshape_train_feature, reshape_train_label, validation_data=(reshape_dev_feature, reshape_dev_label), epochs=200,
          batch_size=256, callbacks=callbacks_list, verbose=1)
# Out:
# Epoch 1/200
# 103/103 [==============================] - 9s 36ms/step - loss: 3.5902 - accuracy: 0.1288 - val_loss: 3.3397 - val_accuracy: 0.1066
# Epoch 2/200
# 103/103 [==============================] - 2s 20ms/step - loss: 2.3827 - accuracy: 0.3924 - val_loss: 3.2429 - val_accuracy: 0.1407
# Epoch 3/200
# 103/103 [==============================] - 2s 20ms/step - loss: 1.8894 - accuracy: 0.5099 - val_loss: 3.0827 - val_accuracy: 0.1706
# Epoch 4/200
# 103/103 [==============================] - 2s 20ms/step - loss: 1.6124 - accuracy: 0.5789 - val_loss: 2.9605 - val_accuracy: 0.2132
# Epoch 5/200
# 103/103 [==============================] - 2s 20ms/step - loss: 1.4223 - accuracy: 0.6259 - val_loss: 3.0289 - val_accuracy: 0.2090
# Epoch 6/200
# 103/103 [==============================] - 2s 20ms/step - loss: 1.2876 - accuracy: 0.6526 - val_loss: 3.0340 - val_accuracy: 0.2175
# Epoch 7/200
# 103/103 [==============================] - 2s 20ms/step - loss: 1.1739 - accuracy: 0.6818 - val_loss: 3.0096 - val_accuracy: 0.2271
# Epoch 8/200
# 103/103 [==============================] - 2s 20ms/step - loss: 1.0780 - accuracy: 0.7069 - val_loss: 3.0017 - val_accuracy: 0.2431
# Epoch 9/200
# 103/103 [==============================] - 2s 20ms/step - loss: 1.0086 - accuracy: 0.7186 - val_loss: 2.9994 - val_accuracy: 0.2527
# Epoch 10/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.9477 - accuracy: 0.7370 - val_loss: 3.0439 - val_accuracy: 0.2559
# Epoch 11/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.8931 - accuracy: 0.7492 - val_loss: 3.0225 - val_accuracy: 0.2719
# Epoch 12/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.8610 - accuracy: 0.7552 - val_loss: 3.1296 - val_accuracy: 0.2569
# Epoch 13/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.8281 - accuracy: 0.7684 - val_loss: 3.0807 - val_accuracy: 0.2612
# Epoch 14/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.7850 - accuracy: 0.7786 - val_loss: 3.1654 - val_accuracy: 0.2708
# Epoch 15/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.7338 - accuracy: 0.7921 - val_loss: 3.1373 - val_accuracy: 0.2783
# Epoch 16/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.7066 - accuracy: 0.7995 - val_loss: 3.1405 - val_accuracy: 0.2751
# Epoch 17/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.6945 - accuracy: 0.7992 - val_loss: 3.1497 - val_accuracy: 0.2889
# Epoch 18/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.6662 - accuracy: 0.8080 - val_loss: 3.2020 - val_accuracy: 0.2729
# Epoch 19/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.6450 - accuracy: 0.8153 - val_loss: 3.2197 - val_accuracy: 0.2942
# Epoch 20/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.6335 - accuracy: 0.8144 - val_loss: 3.3023 - val_accuracy: 0.2964
# Epoch 21/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.6114 - accuracy: 0.8213 - val_loss: 3.2733 - val_accuracy: 0.2996
# Epoch 22/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.5946 - accuracy: 0.8265 - val_loss: 3.3835 - val_accuracy: 0.3017
# Epoch 23/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.5759 - accuracy: 0.8302 - val_loss: 3.3947 - val_accuracy: 0.2921
# Epoch 24/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.5755 - accuracy: 0.8298 - val_loss: 3.3959 - val_accuracy: 0.3017
# Epoch 25/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.5477 - accuracy: 0.8387 - val_loss: 3.4438 - val_accuracy: 0.3006
# Epoch 26/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.5375 - accuracy: 0.8407 - val_loss: 3.4040 - val_accuracy: 0.3070
# Epoch 27/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.5305 - accuracy: 0.8379 - val_loss: 3.4549 - val_accuracy: 0.3081
# Epoch 28/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.5146 - accuracy: 0.8483 - val_loss: 3.4599 - val_accuracy: 0.3049
# Epoch 29/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.5007 - accuracy: 0.8523 - val_loss: 3.5015 - val_accuracy: 0.3134
# Epoch 30/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.4827 - accuracy: 0.8569 - val_loss: 3.5420 - val_accuracy: 0.3081
# Epoch 31/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.4767 - accuracy: 0.8597 - val_loss: 3.5433 - val_accuracy: 0.3006
# Epoch 32/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.4531 - accuracy: 0.8638 - val_loss: 3.5077 - val_accuracy: 0.3156
# Epoch 33/200
# 103/103 [==============================] - 2s 20ms/step - loss: 0.4650 - accuracy: 0.8588 - val_loss: 3.5352 - val_accuracy: 0.3145
# Epoch 34/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.4543 - accuracy: 0.8630 - val_loss: 3.6090 - val_accuracy: 0.3092
# Epoch 35/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.4542 - accuracy: 0.8645 - val_loss: 3.6749 - val_accuracy: 0.3060
# Epoch 36/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.4394 - accuracy: 0.8646 - val_loss: 3.6338 - val_accuracy: 0.3124
# Epoch 37/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.4348 - accuracy: 0.8665 - val_loss: 3.6625 - val_accuracy: 0.2964
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 38/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.4139 - accuracy: 0.8755 - val_loss: 3.6130 - val_accuracy: 0.3113
# Epoch 39/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3613 - accuracy: 0.8915 - val_loss: 3.6370 - val_accuracy: 0.3102
# Epoch 40/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3400 - accuracy: 0.8952 - val_loss: 3.6351 - val_accuracy: 0.3209
# Epoch 41/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3336 - accuracy: 0.8997 - val_loss: 3.6455 - val_accuracy: 0.3156
# Epoch 42/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3293 - accuracy: 0.9005 - val_loss: 3.6698 - val_accuracy: 0.3145
# Epoch 43/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3147 - accuracy: 0.9060 - val_loss: 3.6944 - val_accuracy: 0.3209
# Epoch 44/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3186 - accuracy: 0.9032 - val_loss: 3.7010 - val_accuracy: 0.3209
# Epoch 45/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3066 - accuracy: 0.9083 - val_loss: 3.7192 - val_accuracy: 0.3166
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 46/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2953 - accuracy: 0.9125 - val_loss: 3.7240 - val_accuracy: 0.3145
# Epoch 47/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2964 - accuracy: 0.9118 - val_loss: 3.7279 - val_accuracy: 0.3156
# Epoch 48/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3014 - accuracy: 0.9091 - val_loss: 3.7295 - val_accuracy: 0.3166
# Epoch 49/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2970 - accuracy: 0.9110 - val_loss: 3.7320 - val_accuracy: 0.3156
# Epoch 50/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2986 - accuracy: 0.9108 - val_loss: 3.7318 - val_accuracy: 0.3156
# Epoch 51/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2923 - accuracy: 0.9117 - val_loss: 3.7360 - val_accuracy: 0.3166
# Epoch 52/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.3040 - accuracy: 0.9078 - val_loss: 3.7357 - val_accuracy: 0.3134
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 53/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2906 - accuracy: 0.9120 - val_loss: 3.7354 - val_accuracy: 0.3134
# Epoch 54/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2971 - accuracy: 0.9097 - val_loss: 3.7354 - val_accuracy: 0.3124
# Epoch 55/200
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2908 - accuracy: 0.9116 - val_loss: 3.7355 - val_accuracy: 0.3124

# %% [markdown]
# # Support Vector Machines(SVM)

# %%
from sklearn.preprocessing import StandardScaler
def generate_feature(data):
    scalar = StandardScaler()
    final_feature = []
    for row in data:
        final_feature.append(process_data(row))
    return scalar.fit_transform(np.array(final_feature))

def process_data(data):
    processed_data = []
    time_data = data.reshape(16,60)
    mean = []
    median = []
    std = []
    for i in range(60):
        mean.append(np.mean(time_data[:,i]))
        median.append(np.median(time_data[:,i]))
        std.append(np.std(time_data[:,i]))

    processed_data = mean + median + std
    return processed_data

# %%
svm_train_feature = generate_feature(train_feature)
svm_dev_feature = generate_feature(dev_feature)

# %%
def accuracy(predict, gold):
    acc = 0
    for pos in range(len(predict)):
        if(predict[pos] ==  gold[pos]):
            acc += 1
    accuracy = acc / len(predict)
    return accuracy

# %%
from sklearn import svm
SVM = svm.SVC()
SVM.fit(svm_train_feature, train_label)
predict = SVM.predict(svm_dev_feature)
opredict = SVM.predict(svm_train_feature)

# %%
print(accuracy(predict, dev_label))
print(accuracy(opredict, train_label))
# Out:
# 0.3720682302771855
# 0.72770113632045

# %% [markdown]
# # Convolution Neural Network(CNN)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler
import torch
import torch.nn as nn
from transformers import AdamW
import random
import numpy as np
from numpy import argmax

# %%
batch_size = 64

cnn_train_label = train_label[:] - 1
train_tensor = torch.Tensor(reshape_train_feature)
train_label_tensor = torch.LongTensor(np.array(cnn_train_label))
train_data = TensorDataset(train_tensor,train_label_tensor)
train_loader = DataLoader(train_data, sampler=RandomSampler(train_data), batch_size=batch_size)
 
cnn_dev_label = dev_label[:] - 1
dev_tensor = torch.Tensor(reshape_dev_feature)
dev_label_tensor = torch.LongTensor(np.array(cnn_dev_label))
dev_t_data = TensorDataset(dev_tensor, dev_label_tensor)
dev_loader = DataLoader(dev_t_data, shuffle=False, batch_size=batch_size)

# %% [markdown]
# ## Construction of network

# %%
class Conv_MLP(nn.Module):
    def __init__(self, input_dim, output_dim, kernel_size, dropout):
        super().__init__()
        self.conv1 = nn.Conv1d(input_dim, 300, kernel_size=kernel_size)
        self.maxpool1 = nn.MaxPool1d(kernel_size=14)
        self.relu = nn.ReLU()
        self.layer = nn.Linear(300, 100)
        self.predictor = nn.Linear(100, output_dim)
        self.dropout = nn.Dropout(dropout)
    def forward(self, data):
        data = data.permute(0, 2, 1)
        conv_layer = self.conv1(data)
        out = self.relu(conv_layer)
        out = self.maxpool1(out).squeeze(2)
        out = self.layer(out)
        out = self.relu(out)
        out = self.dropout(out)
        result = self.predictor(out)
        return result

# %%
input_dim = 60
output_dim = 49
kernel_size = 3
dropout_rate = 0.1
cnn = Conv_MLP(input_dim, output_dim,kernel_size, dropout_rate)
cnn.cuda()
# Out:
# Conv_MLP(
#   (conv1): Conv1d(60, 300, kernel_size=(3,), stride=(1,))
#   (maxpool1): MaxPool1d(kernel_size=14, stride=14, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (layer): Linear(in_features=300, out_features=100, bias=True)
#   (predictor): Linear(in_features=100, out_features=49, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
# optimizer 
learning_rate = 1e-3
optimizer = AdamW(cnn.parameters(), lr = learning_rate, eps=1e-8)
# loss
criterion = nn.CrossEntropyLoss()
criterion.cuda()
# Out:
# CrossEntropyLoss()

# %%
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
# Train the Model
epochs = 100
seed_val = 36
best_valid_score = 0

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)

training_stats = [] # used to store the training information


for epoch_i in range(epochs):
    
    print("")
    print("======== Epoch {:} / {:} ========".format(epoch_i + 1, epochs))
    print("Training...")
    
    total_train_loss = 0
    
    cnn.train()
    
    for step, batch in enumerate(train_loader):
        
        if (step + 1) % 10 == 0 and not step == 0:
            print("Batch {} of {}".format(step+1, len(train_loader)))
        
        batch_input_data = batch[0].cuda()
        batch_labels = batch[1].cuda()


        optimizer.zero_grad()
        logits = cnn(batch_input_data)
        loss = criterion(logits, batch_labels)
        total_train_loss += loss.item()
        loss.backward()
        
        optimizer.step()
        
    
    avg_train_loss = total_train_loss / len(train_loader)
    
    print("")
    print(" Average Training Loss is {:2f}".format(avg_train_loss))
    
    # Now perform validation
    
    print("")
    print("Running Validation...")
    
    cnn.eval()
    
    total_eval_accuracy = 0
    total_eval_loss = 0
    
    for batch in dev_loader:
        dev_input_data = batch[0].cuda()
        dev_labels = batch[1].cuda()
        
        with torch.no_grad():
            logits = cnn(dev_input_data)
            
            loss = criterion(logits, dev_labels)

        total_eval_loss += loss.item()
        preds = logits.detach().cpu().numpy()
        
        label_ids = dev_labels.cpu().numpy()
        
        total_eval_accuracy += flat_accuracy(preds, label_ids)

    avg_val_loss = total_eval_loss / len(dev_loader)
    avg_val_accuracy = total_eval_accuracy / len(dev_loader)
    training_stats.append(avg_val_loss)
    print("Validation loss :{}".format(avg_val_loss))
    print("Accuracy is {}".format(avg_val_accuracy))
    
    if avg_val_accuracy > best_valid_score:
        best_valid_score = avg_val_accuracy
        torch.save(cnn.state_dict(), 'model.pt')
    
    
print("")
print("Training Complete!...")
print("best validation score", best_valid_score)
# Out:
# ======== Epoch 1 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 3.511074
#
# Running Validation...
# Validation loss :3.2817334175109862
# Accuracy is 0.15590277777777778
#
# ======== Epoch 2 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 2.591633
#
# Running Validation...
# Validation loss :2.9667496840159098
# Accuracy is 0.2210813492063492
#
# ======== Epoch 3 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 2.295426
#
# Running Validation...
# Validation loss :3.0456820329030356
# Accuracy is 0.2164186507936508
#
# ======== Epoch 4 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 2.104179
#
# Running Validation...
# Validation loss :2.9458017190297445
# Accuracy is 0.24404761904761904
#
# ======== Epoch 5 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.955295
#
# Running Validation...
# Validation loss :2.962982511520386
# Accuracy is 0.2535218253968254
#
# ======== Epoch 6 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.888952
#
# Running Validation...
# Validation loss :3.184675184885661
# Accuracy is 0.29732142857142857
#
# ======== Epoch 7 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.721299
#
# Running Validation...
# Validation loss :3.110921335220337
# Accuracy is 0.28789682539682543
#
# ======== Epoch 8 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.667471
#
# Running Validation...
# Validation loss :3.1546597639719645
# Accuracy is 0.30252976190476194
#
# ======== Epoch 9 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.600858
#
# Running Validation...
# Validation loss :2.9928515434265135
# Accuracy is 0.3061507936507937
#
# ======== Epoch 10 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.540021
#
# Running Validation...
# Validation loss :3.344744396209717
# Accuracy is 0.2873015873015873
#
# ======== Epoch 11 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.484202
#
# Running Validation...
# Validation loss :3.1702495416005454
# Accuracy is 0.27480158730158727
#
# ======== Epoch 12 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.469420
#
# Running Validation...
# Validation loss :3.3279670397440593
# Accuracy is 0.3431547619047619
#
# ======== Epoch 13 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.352437
#
# Running Validation...
# Validation loss :3.2374982674916586
# Accuracy is 0.3296626984126984
#
# ======== Epoch 14 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.368537
#
# Running Validation...
# Validation loss :3.302824831008911
# Accuracy is 0.3175595238095238
#
# ======== Epoch 15 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.330913
#
# Running Validation...
# Validation loss :3.359996032714844
# Accuracy is 0.3171130952380953
#
# ======== Epoch 16 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.360145
#
# Running Validation...
# Validation loss :3.460528087615967
# Accuracy is 0.3577876984126984
#
# ======== Epoch 17 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.246051
#
# Running Validation...
# Validation loss :3.519051218032837
# Accuracy is 0.3259920634920635
#
# ======== Epoch 18 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.249922
#
# Running Validation...
# Validation loss :3.636887296040853
# Accuracy is 0.3473214285714286
#
# ======== Epoch 19 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.208907
#
# Running Validation...
# Validation loss :3.539242649078369
# Accuracy is 0.323859126984127
#
# ======== Epoch 20 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.207837
#
# Running Validation...
# Validation loss :3.6811784426371257
# Accuracy is 0.3296626984126984
#
# ======== Epoch 21 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.191535
#
# Running Validation...
# Validation loss :3.503612168629964
# Accuracy is 0.3645337301587302
#
# ======== Epoch 22 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.203824
#
# Running Validation...
# Validation loss :3.6965901851654053
# Accuracy is 0.34112103174603176
#
# ======== Epoch 23 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.125718
#
# Running Validation...
# Validation loss :3.56549129486084
# Accuracy is 0.34573412698412703
#
# ======== Epoch 24 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.138748
#
# Running Validation...
# Validation loss :3.7762717247009276
# Accuracy is 0.3451884920634921
#
# ======== Epoch 25 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.093428
#
# Running Validation...
# Validation loss :3.904834493001302
# Accuracy is 0.35094246031746035
#
# ======== Epoch 26 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.092658
#
# Running Validation...
# Validation loss :3.757157325744629
# Accuracy is 0.3467757936507937
#
# ======== Epoch 27 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.094629
#
# Running Validation...
# Validation loss :3.908318551381429
# Accuracy is 0.3213293650793651
#
# ======== Epoch 28 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.148354
#
# Running Validation...
# Validation loss :3.4148850440979004
# Accuracy is 0.3312003968253968
#
# ======== Epoch 29 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.068500
#
# Running Validation...
# Validation loss :3.760305150349935
# Accuracy is 0.320734126984127
#
# ======== Epoch 30 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.080103
#
# Running Validation...
# Validation loss :3.5988982200622557
# Accuracy is 0.3697420634920635
#
# ======== Epoch 31 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.079656
#
# Running Validation...
# Validation loss :3.6403271675109865
# Accuracy is 0.3640376984126984
#
# ======== Epoch 32 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.025698
#
# Running Validation...
# Validation loss :3.54075338045756
# Accuracy is 0.35833333333333334
#
# ======== Epoch 33 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.001436
#
# Running Validation...
# Validation loss :4.079819552103678
# Accuracy is 0.3765376984126984
#
# ======== Epoch 34 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.052744
#
# Running Validation...
# Validation loss :3.8701993465423583
# Accuracy is 0.39171626984126984
#
# ======== Epoch 35 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.011162
#
# Running Validation...
# Validation loss :4.094033432006836
# Accuracy is 0.35252976190476193
#
# ======== Epoch 36 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.993355
#
# Running Validation...
# Validation loss :3.9551912466684978
# Accuracy is 0.36507936507936506
#
# ======== Epoch 37 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.997487
#
# Running Validation...
# Validation loss :4.477962509791056
# Accuracy is 0.3446924603174603
#
# ======== Epoch 38 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.084570
#
# Running Validation...
# Validation loss :4.254300181070963
# Accuracy is 0.2909722222222222
#
# ======== Epoch 39 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.023679
#
# Running Validation...
# Validation loss :4.050914510091146
# Accuracy is 0.3697420634920635
#
# ======== Epoch 40 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.958569
#
# Running Validation...
# Validation loss :4.199813493092855
# Accuracy is 0.33010912698412703
#
# ======== Epoch 41 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.055797
#
# Running Validation...
# Validation loss :4.178480323155721
# Accuracy is 0.36924603174603177
#
# ======== Epoch 42 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.039142
#
# Running Validation...
# Validation loss :3.720226589838664
# Accuracy is 0.3557043650793651
#
# ======== Epoch 43 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.040516
#
# Running Validation...
# Validation loss :4.041707626978556
# Accuracy is 0.35252976190476193
#
# ======== Epoch 44 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.054283
#
# Running Validation...
# Validation loss :4.058780352274577
# Accuracy is 0.34424603174603174
#
# ======== Epoch 45 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.915680
#
# Running Validation...
# Validation loss :4.479423252741496
# Accuracy is 0.348859126984127
#
# ======== Epoch 46 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.973781
#
# Running Validation...
# Validation loss :4.109235827128092
# Accuracy is 0.33591269841269844
#
# ======== Epoch 47 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.973305
#
# Running Validation...
# Validation loss :4.067063156763712
# Accuracy is 0.3723214285714286
#
# ======== Epoch 48 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.905267
#
# Running Validation...
# Validation loss :4.157399543126425
# Accuracy is 0.3701884920634921
#
# ======== Epoch 49 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.877722
#
# Running Validation...
# Validation loss :4.024225775400797
# Accuracy is 0.3474206349206349
#
# ======== Epoch 50 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.919534
#
# Running Validation...
# Validation loss :4.532756360371907
# Accuracy is 0.3499007936507937
#
# ======== Epoch 51 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.960535
#
# Running Validation...
# Validation loss :4.192766364415487
# Accuracy is 0.36929563492063494
#
# ======== Epoch 52 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 1.022126
#
# Running Validation...
# Validation loss :4.570410760243734
# Accuracy is 0.3848214285714286
#
# ======== Epoch 53 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.923379
#
# Running Validation...
# Validation loss :4.697818740208944
# Accuracy is 0.36344246031746036
#
# ======== Epoch 54 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.862035
#
# Running Validation...
# Validation loss :4.658234167098999
# Accuracy is 0.3640376984126984
#
# ======== Epoch 55 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.985631
#
# Running Validation...
# Validation loss :4.346723159154256
# Accuracy is 0.35987103174603174
#
# ======== Epoch 56 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# ...
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.762647
#
# Running Validation...
# Validation loss :4.9037215868632
# Accuracy is 0.3811507936507937
#
# ======== Epoch 83 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.866134
#
# Running Validation...
# Validation loss :5.216083176930746
# Accuracy is 0.3624503968253968
#
# ======== Epoch 84 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.903457
#
# Running Validation...
# Validation loss :5.579105408986409
# Accuracy is 0.3817460317460318
#
# ======== Epoch 85 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.863913
#
# Running Validation...
# Validation loss :5.240158526102702
# Accuracy is 0.3541666666666667
#
# ======== Epoch 86 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.826569
#
# Running Validation...
# Validation loss :5.157268079121907
# Accuracy is 0.3838789682539682
#
# ======== Epoch 87 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.798525
#
# Running Validation...
# Validation loss :5.3887608528137205
# Accuracy is 0.36929563492063494
#
# ======== Epoch 88 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.841189
#
# Running Validation...
# Validation loss :5.617785390218099
# Accuracy is 0.35094246031746035
#
# ======== Epoch 89 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.832583
#
# Running Validation...
# Validation loss :5.079442660013835
# Accuracy is 0.3175595238095238
#
# ======== Epoch 90 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.836956
#
# Running Validation...
# Validation loss :5.207954279581705
# Accuracy is 0.32123015873015875
#
# ======== Epoch 91 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.772416
#
# Running Validation...
# Validation loss :5.225216436386108
# Accuracy is 0.3842757936507937
#
# ======== Epoch 92 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.751900
#
# Running Validation...
# Validation loss :5.880957317352295
# Accuracy is 0.3603670634920635
#
# ======== Epoch 93 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.781173
#
# Running Validation...
# Validation loss :5.511192591985067
# Accuracy is 0.36860119047619044
#
# ======== Epoch 94 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.859213
#
# Running Validation...
# Validation loss :5.359881909688314
# Accuracy is 0.3740079365079365
#
# ======== Epoch 95 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.803681
#
# Running Validation...
# Validation loss :5.758675003051758
# Accuracy is 0.38278769841269844
#
# ======== Epoch 96 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.805847
#
# Running Validation...
# Validation loss :5.447676006952921
# Accuracy is 0.3707837301587302
#
# ======== Epoch 97 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.794793
#
# Running Validation...
# Validation loss :5.084347279866536
# Accuracy is 0.33690476190476193
#
# ======== Epoch 98 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.761174
#
# Running Validation...
# Validation loss :6.313734912872315
# Accuracy is 0.3682043650793651
#
# ======== Epoch 99 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.801541
#
# Running Validation...
# Validation loss :5.7547471205393474
# Accuracy is 0.3796626984126984
#
# ======== Epoch 100 / 100 ========
# Training...
# Batch 10 of 412
# Batch 20 of 412
# Batch 30 of 412
# Batch 40 of 412
# Batch 50 of 412
# Batch 60 of 412
# Batch 70 of 412
# Batch 80 of 412
# Batch 90 of 412
# Batch 100 of 412
# Batch 110 of 412
# Batch 120 of 412
# Batch 130 of 412
# Batch 140 of 412
# Batch 150 of 412
# Batch 160 of 412
# Batch 170 of 412
# Batch 180 of 412
# Batch 190 of 412
# Batch 200 of 412
# Batch 210 of 412
# Batch 220 of 412
# Batch 230 of 412
# Batch 240 of 412
# Batch 250 of 412
# Batch 260 of 412
# Batch 270 of 412
# Batch 280 of 412
# Batch 290 of 412
# Batch 300 of 412
# Batch 310 of 412
# Batch 320 of 412
# Batch 330 of 412
# Batch 340 of 412
# Batch 350 of 412
# Batch 360 of 412
# Batch 370 of 412
# Batch 380 of 412
# Batch 390 of 412
# Batch 400 of 412
# Batch 410 of 412
#
#  Average Training Loss is 0.794668
#
# Running Validation...
# Validation loss :6.729886404673258
# Accuracy is 0.37336309523809524
#
# Training Complete!...
# best validation score 0.3995039682539682

# %%
predictions = []
model = Conv_MLP(input_dim, output_dim,kernel_size, dropout_rate)
model.load_state_dict(torch.load('model.pt'))
model.eval()

# test_nor_data = scalar.fit_transform(test_data)

# test_nor_data = test_nor_data.reshape((-1, 16 ,60))

# test_tensor = torch.Tensor(test_nor_data)


# test_t_data = TensorDataset(test_tensor)

# test_loader = DataLoader(test_t_data, shuffle=False, batch_size=2959)

# mylist = []
# for ele in test_loader:
#     output = model(ele[0])
#     preds = output.detach().cpu().numpy()
#     mylist.append(np.argmax(preds, axis=1).flatten())
# Out:
# Conv_MLP(
#   (conv1): Conv1d(60, 300, kernel_size=(3,), stride=(1,))
#   (maxpool1): MaxPool1d(kernel_size=14, stride=14, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (layer): Linear(in_features=300, out_features=100, bias=True)
#   (predictor): Linear(in_features=100, out_features=49, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %% [markdown]
# # Using bagging to get the final result

# %%
models = [rnn, SVM, cnn]
model_name = ["rnn", "svm", "cnn"]
model_name = np.array(model_name)

# %%
test = pd.read_csv('test.csv', header=None)
test_feature = np.array(test.iloc[:,1:])

# %%
test_feature.shape
# Out:
# (2959, 960)

# %%
def final_prediction(models, model_name, test_feature):
    reshape_test_feature = reshape_feature(test_feature)
    all_predictions = []
    for i in range(len(models)):
        if(model_name[i] == "rnn"):
            result = models[i].predict(reshape_test_feature)
            final_result = []
            for i in result:
                final_result.append(i.tolist().index(max(i))+1)
            all_predictions.append(final_result)
        elif(model_name[i] == "svm"):
            svm_test_feature = generate_feature(test_feature)
            result = models[i].predict(svm_test_feature)
            all_predictions.append(result)
        elif(model_name[i] == "cnn"):
            model = Conv_MLP(input_dim, output_dim,kernel_size, dropout_rate)
            model.load_state_dict(torch.load('model.pt'))
            test_tensor = torch.Tensor(reshape_test_feature)
            test_t_data = TensorDataset(test_tensor)
            test_loader = DataLoader(test_t_data, shuffle=False, batch_size=2959)
            final_result = []
            for ele in test_loader:
                output = model(ele[0])
                preds = output.detach().cpu().numpy()
                final_result.append(np.argmax(preds, axis=1).flatten())
            print(final_result)
            all_predictions.append(final_result[0])
    prediction = bagging(all_predictions)
    return prediction

def bagging(labels):
    final_predict = []
    for i in range(len(labels[0])):
        one_row = []
        for l in labels:
            one_row.append(l[i])
        maxlabel = max(one_row, key = one_row.count)
        final_predict.append(maxlabel)
    return final_predict

# %%
prediction = final_prediction(models, model_name, test_feature)

# %%
import csv
def out_file(result):
    out_f = open("predict_f.csv", 'w', newline='')
    writer = csv.writer(out_f)
    head = ["ID", "Category"]
    writer.writerow(head)
    count = 0
    for i in result:
        writer.writerow([count, i+1])
        count += 1

# %%
out_file(prediction)
